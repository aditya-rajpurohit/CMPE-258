# %% [markdown]
# # Install Keras Hub

# %%
# install kerashub
# !pip install git+https://github.com/keras-team/keras-hub.git -q

# set the keras backend
import os
os.environ["KERAS_BACKEND"] = "jax"

# import necessary libraries
import keras_hub
import keras
import tensorflow as tf
import time
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-nlp 0.18.1 requires keras-hub==0.18.1, but you have keras-hub 0.21.0.dev0 which is incompatible.

# %%
# enable mixed precision for performance
keras.mixed_precision.set_global_policy("mixed_float16")

# %% [markdown]
# # Load the Preprocessor and Model

# %%
# load the GPT-2 preprocessor
preprocessor = keras_hub.models.GPT2CausalLMPreprocessor.from_preset(
    "gpt2_base_en",
    sequence_length=128,
)

# load the GPT-2 model with the preprocessor
gpt2_lm = keras_hub.models.GPT2CausalLM.from_preset(
    "gpt2_base_en", preprocessor=preprocessor
)
# Out:
# ...
# 100%|██████████| 618/618 [00:00<00:00, 813kB/s]
# ...
# 100%|██████████| 0.99M/0.99M [00:01<00:00, 913kB/s]
# ...
# 100%|██████████| 446k/446k [00:00<00:00, 515kB/s]
# ...
# 100%|██████████| 475M/475M [00:25<00:00, 19.4MB/s]

# %% [markdown]
# # Generate Text

# %%
# define a prompt
prompt = "Once upon a time in a land far away"

# generate text
start_time = time.time()
output = gpt2_lm.generate(prompt, max_length=100)
end_time = time.time()

# display the generated text
print("Generated Text:")
print(output)
print(f"\nTime taken: {end_time - start_time:.2f} seconds")
# Out:
# Generated Text:
# Once upon a time in a land far away the sun was a beautiful, bright and bright star, and when the moon was gone, all was darkness.
#
# But now it is a bright and bright star. And the stars are bright and bright.
#
# And now I am going to show you how to make a little light from a candle, and I will show you how to light a lamp.
#
# And you will see how to make a little lamp from a candle, and
#
# Time taken: 11.20 seconds

# %%
# define a prompt
prompt = "The future of artificial intelligence depends on"

# generate text
start_time = time.time()
output = gpt2_lm.generate(prompt, max_length=100)
end_time = time.time()

# display the generated text
print("Generated Text:")
print(output)
print(f"\nTime taken: {end_time - start_time:.2f} seconds")
# Out:
# Generated Text:
# The future of artificial intelligence depends on how much computing power it has. In the early days of computing, computers were only capable of performing simple tasks like reading and writing, and they were not capable of doing other tasks like searching. Now, however, the computers are able to perform complex and complex tasks that require complex computing power.
#
# The new computer is a "machine learning" device that uses machine learning techniques to train its neural networks to recognize and respond to information that is presented to it
#
# Time taken: 3.52 seconds
